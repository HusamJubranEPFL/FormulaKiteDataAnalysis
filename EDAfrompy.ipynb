# %%
from twa_analysis import analyze_session

analyze_session(
    "DataFromSailnjord/06_06_Run5/Karl Maeder.csv",
    "DataFromSailnjord/06_06_Run5/SenseBoard.csv"
)
# Out:
# Max gap in first range: (35, 146, 111)
# Max gap in second range: (244, 311, 67)
