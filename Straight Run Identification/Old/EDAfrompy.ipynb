# %%
from twa_analysis import analyze_session

analyze_session(
    "../Data_Sailnjord/Straight_lines/06_06/06_06_Run5/Karl Maeder.csv",
    "../Data_Sailnjord/Straight_lines/06_06/06_06_Run5/SenseBoard.csv"
)
# Out:
# Max gap in first range: [1028, 1751]
# Max gap in second range: [2857, 3722]
